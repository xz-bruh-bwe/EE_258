# %% [markdown]
# ### CURRENT DIRECTORY

# %%
pwd
# Out:
# 'C:\\Users\\Baron\\Desktop\\EE_258_Repo\\EE_258\\ML_PATH_EE258\\EE258_env\\projects'

# %% [markdown]
# ### Pathing
#     a. Baron's Pathing:
#         Main Location: 'C:\\Users\\Baron\\Desktop\\EE_258_Repo\\EE_258\\ML_PATH_EE258\\EE258_env\\projects'
#         Dataset: C:\Users\Baron\Documents\Grad_School\EE_258\project
#
#     b. Hunter's Pathing:

# %% [markdown]
# ### EE 258 Project Code
#
# Table of Contents
#
#     Part a) Preliminary Setup
#     Part b) Dataset Description
#     Part c) Dataset Visualization
#     Part d) Pre Processing
#     Part e) BASELINE MODEL:
#     Part f) MODELS UTILIZED:
#     Part g) MODEL IMPROVEMENTS
#     Part h) PERFORMANCE & CONCLUSIONS:
#     Part e)

# %% [markdown]
# ### Part a) Preliminary Setup
#     1. Import Necessary Libraries
#     2. Import the Dataset

# %%
#1. Import Necessary Liobraries
import pandas as pd 
import numpy as np 
import os

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

# %%
#2. Import the Dataset
##  Baron's Path
dataset_loc = r"C:\Users\Baron\Documents\Grad_School\EE_258\project\CUB_200_2011"

## Hunter's Path (Uncomment as needed)
#dataset_loc = r"Relace with path"


# Load key files
images_df = pd.read_csv(f"{dataset_loc}/images.txt", sep=" ", names=["image_id", "filepath"])
labels_df = pd.read_csv(f"{dataset_loc}/image_class_labels.txt", sep=" ", names=["image_id", "class_id"])
classes_df = pd.read_csv(f"{dataset_loc}/classes.txt", sep=" ", names=["class_id", "class_name"])
split_df = pd.read_csv(f"{dataset_loc}/train_test_split.txt", sep=" ", names=["image_id", "is_train"])


# Merge into a single DataFrame
birds_df = images_df.merge(labels_df, on="image_id")
birds_df = birds_df.merge(split_df, on="image_id")
birds_df = birds_df.merge(classes_df, on="class_id")

# Add full image path
birds_df["images_filepath"] = dataset_loc + "/images/" + birds_df["filepath"]

# %% [markdown]
# ### Part b) Dataset Description
#
#     1. General Info
#     2. Describing the Dataset
#     3. Head of the Dataset
#     4. Describing the characteristicts of the images
#     4. Creating General Dataframes (For later use)

# %%
# 1. General Info
birds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11788 entries, 0 to 11787
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   image_id         11788 non-null  int64
#  1   filepath         11788 non-null  object
#  2   class_id         11788 non-null  int64
#  3   is_train         11788 non-null  int64
#  4   class_name       11788 non-null  object
#  5   images_filepath  11788 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 552.7+ KB

# %%
#2. Describing the dataset
birds_df.describe()
# Out:
#            image_id      class_id      is_train
# count  11788.000000  11788.000000  11788.000000
# mean    5894.500000    101.126315      0.508483
# std     3403.046821     57.476826      0.499949
# min        1.000000      1.000000      0.000000
# 25%     2947.750000     51.000000      0.000000
# 50%     5894.500000    101.000000      1.000000
# 75%     8841.250000    151.000000      1.000000
# max    11788.000000    200.000000      1.000000

# %%
#3. Head of the Dataset (Used to see a quick glimpse of the dataset)
birds_df.head(120)
# Out:
#      image_id                                           filepath  class_id  \
# 0           1  001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 1           2  001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 2           3  001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 3           4  001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 4           5  001.Black_footed_Albatross/Black_Footed_Albatr...         1
# ..        ...                                                ...       ...
# 115       116  002.Laysan_Albatross/Laysan_Albatross_0083_756...         2
# 116       117  002.Laysan_Albatross/Laysan_Albatross_0094_101...         2
# 117       118  002.Laysan_Albatross/Laysan_Albatross_0103_504...         2
# 118       119  002.Laysan_Albatross/Laysan_Albatross_0079_506...         2
# 119       120  002.Laysan_Albatross/Laysan_Albatross_0051_102...         2
#
#      is_train                  class_name  \
# 0           0  001.Black_footed_Albatross
# 1           1  001.Black_footed_Albatross
# 2           0  001.Black_footed_Albatross
# 3           1  001.Black_footed_Albatross
# 4           1  001.Black_footed_Albatross
# ..        ...                         ...
# 115         1        002.Laysan_Albatross
# 116         1        002.Laysan_Albatross
# 117         0        002.Laysan_Albatross
# 118         0        002.Laysan_Albatross
# 119         1        002.Laysan_Albatross
#
#                                        images_filepath
# 0    C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 1    C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 2    C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 3    C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 4    C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# ..                                                 ...
# 115  C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 116  C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 117  C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 118  C:\Users\Baron\Documents\Grad_School\EE_258\pr...
# 119  C:\Users\Baron\Documents\Grad_School\EE_258\pr...
#
# [120 rows x 6 columns]

# %%
# Get the first 5 unique folder names from birds_df
first_five_folders = birds_df['filepath'].apply(lambda x: x.split('/')[0]).unique()[:5]

# Loop through the folders and count images
for folder in first_five_folders:
    folder_path = os.path.join(dataset_loc, 'images', folder)
    image_count = len([
        f for f in os.listdir(folder_path)
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ])
    print(f"The folder '{folder}' contains {image_count} images.")
# Out:
# The folder '001.Black_footed_Albatross' contains 60 images.
# The folder '002.Laysan_Albatross' contains 60 images.
# The folder '003.Sooty_Albatross' contains 58 images.
# The folder '004.Groove_billed_Ani' contains 60 images.
# The folder '005.Crested_Auklet' contains 44 images.

# %%
for i in range(5):
    image_path = birds_df['images_filepath'].iloc[i]
    if os.path.exists(image_path):
        with Image.open(image_path) as img:
            print(img.size)  # Only outputs (width, height)
# Out:
# (500, 335)
# (500, 336)
# (500, 347)
# (415, 500)
# (331, 380)

# %% [markdown]
# ### Part C) Dataset Visualization

# %%
plt.figure(figsize=(12, 5))
sns.histplot(birds_df['class_name'], bins=50, kde=False)
plt.xticks(rotation=90)
plt.title("Image Count per Bird Species")
plt.ylabel("Number of Images")
plt.tight_layout()
plt.show()

# %%
# Lists to hold width and height values
widths = []
heights = []

# Loop through all images
for path in birds_df["images_filepath"]:
    try:
        with Image.open(path) as img:
            width, height = img.size
            widths.append(width)
            heights.append(height)
    except Exception as e:
        print(f"Skipped {path}: {e}")

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(widths, heights, alpha=0.5)
plt.title("Image Dimensions: Width vs Height")
plt.xlabel("Width (pixels)")
plt.ylabel("Height (pixels)")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# Number of classes
NUM_CLASSES = birds_df['class_id'].nunique()

# Get one image per class
sample_df = birds_df.groupby('class_id').first().reset_index()

# Grid layout
cols = 20
rows = NUM_CLASSES // cols + int(NUM_CLASSES % cols > 0)
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))
axes = axes.flatten()

for i, (_, row) in enumerate(sample_df.iterrows()):
    img = Image.open(row['images_filepath'])
    axes[i].imshow(img)
    axes[i].axis('off')
    # Shorten title by removing class ID prefix (e.g., "001.Red_winged_Blackbird" → "Red_winged_Blackbird")
    class_name = row['class_name'].split('.')[-1]
    axes[i].set_title(class_name, fontsize=6)

# Turn off unused axes
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
### Part D) Image Set Preprocessing

# %%
from PIL import Image
from tqdm import tqdm

# Original and new directories
original_dir = os.path.join(dataset_loc, 'images')
processed_dir = os.path.join(dataset_loc, 'images_p')

# Target size
target_size = (500, 375)

# Walk through all subfolders and images
for root, dirs, files in os.walk(original_dir):
    for file in tqdm(files, desc="Processing images"):
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            # Full path to original image
            img_path = os.path.join(root, file)

            # Create corresponding path in new directory
            relative_path = os.path.relpath(img_path, original_dir)
            new_path = os.path.join(processed_dir, relative_path)

            # Create subdirectory if it doesn't exist
            os.makedirs(os.path.dirname(new_path), exist_ok=True)

            try:
                # Open, resize, and save image
                img = Image.open(img_path).convert('RGB')
                img_resized = img.resize(target_size)
                img_resized.save(new_path)
            except Exception as e:
                print(f"Failed to process {img_path}: {e}")
# Out:
# Processing images: 0it [00:00, ?it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 111.64it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.45it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 108.01it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.73it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 101.53it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 95.12it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 53/53 [00:00<00:00, 96.74it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 109.59it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 100.31it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.00it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.21it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 56/56 [00:00<00:00, 98.97it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.27it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.14it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 97.48it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 93.79it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 57/57 [00:00<00:00, 99.57it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 111.15it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 102.81it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 98.83it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.88it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 56/56 [00:00<00:00, 103.87it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 103.38it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 105.56it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 91.03it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.75it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.87it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 87.32it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.78it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.26it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 96.95it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 53/53 [00:00<00:00, 97.70it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 91.97it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 99.17it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.24it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 93.19it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 106.30it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 94.39it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 91.65it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 96.93it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.40it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.21it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 93.13it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 109.90it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 85.76it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.64it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.59it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.85it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.63it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.54it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 106.50it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.90it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.71it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 88.46it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 94.71it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 96.15it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.39it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 104.04it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.95it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 102.87it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.05it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.07it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.40it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 77.20it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 111.26it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.24it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.72it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.61it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.64it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.35it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 117.19it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 118.79it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.65it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.52it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 57/57 [00:00<00:00, 100.75it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.79it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.31it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 104.81it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.83it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.76it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 110.08it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.45it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.79it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 53/53 [00:00<00:00, 112.06it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.05it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.42it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.27it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.21it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.35it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.24it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.62it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.38it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.71it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.91it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.71it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.44it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 99.87it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 105.13it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.63it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 96.18it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 104.19it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.83it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.74it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.36it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 49/49 [00:00<00:00, 109.12it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.03it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 101.11it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 109.70it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 105.45it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 88.50it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 105.54it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 108.41it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 105.73it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.63it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 100.77it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.14it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 98.03it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.07it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 99.38it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.75it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.46it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.13it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.43it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 105.45it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 98.50it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 94.24it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.00it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.26it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.96it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.80it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.05it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.73it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 92.23it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.02it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 105.55it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 107.24it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.90it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 105.84it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 81.07it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 91.32it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 108.72it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.53it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 104.81it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.75it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.23it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.42it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.78it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.89it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 94.07it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 93.16it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 104.66it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.37it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 104.30it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.04it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.74it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.35it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 104.80it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 105.49it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 100.09it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 102.38it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.93it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 102.02it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 94.14it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 105.30it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 89.81it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 99.00it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.16it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 90.21it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 95.64it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 103.63it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.99it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.29it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.45it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.10it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.16it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.80it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 101.99it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 56/56 [00:00<00:00, 100.24it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 97.96it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.78it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 106.46it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.08it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.07it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 92.51it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.80it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 71.24it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 86.39it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 85.50it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 88.03it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 58/58 [00:00<00:00, 88.55it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 89.07it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 87.97it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.58it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 95.98it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 99.92it/s]
# Processing images: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 101.57it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.40it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 89.69it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 98.34it/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 97.92it/s]
